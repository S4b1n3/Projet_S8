# %% [markdown]
# Commandes:
#
# -simulation:
#
#             batsim -p platforms/cluster_energy.xml -w workloads/workload_energy.json -e ./output/ -E
#
# -scheduler:
#
#             batsched -v energy_bf --variant_options_filepath='workloads/config_energy.json'
#
#             pybatsim scheduler/fcfsSchedSleep.py --options-file='workloads/config_energy_py.json'
#
# -gantt:
#
#             ./evalys-master/examples/poquetm/plot_energy_info.py --gantt -j output/_jobs.csv -p output/_pstate_changes.csv --off 13 --switchon '-1' --switchoff '-2'
#
# complete gantt:
#
#             ./evalys-master/examples/poquetm/plot_energy_info.py --gantt -j output/_jobs.csv -p output/_pstate_changes.csv --off 13 --switchon '-1' --switchoff '-2' --ru -m output/_machine_states.csv -e output/_consumed_energy.csv --power
#
# -comparative power/energy chart:
#
#             ./evalys-master/examples/poquetm/plot_energy_info.py -e output/_consumed_energy.csv output/_consumed_energy1.csv  --names 'normal' 'moyenne' --power --energy

# %%
from evalys.jobset import JobSet
import matplotlib.pyplot as plt
import subprocess

# %%
js = JobSet.from_csv("output/_jobs.csv")
js.plot(with_details=True)
plt.show()
# Out:
# /home/fsociety/.local/lib/python3.6/site-packages/evalys/metrics.py:47: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   df.ix[df['execution_time'] == -1, 'finish_time'] = max_time
# /home/fsociety/.local/lib/python3.6/site-packages/evalys/metrics.py:48: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   df.ix[df['execution_time'] == -1, 'starting_time'] = max_time
