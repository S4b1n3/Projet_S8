# %% [markdown]
# Commandes:
#
# -simulation: batsim -p platforms/cluster_energy_128.xml -w workloads/workload_energy.json -e ./output/ -E
#
# -scheduler: batsched -v energy_bf --variant_options_filepath='workloads/config_energy.json'
#
# -gantt: ./evalys-master/examples/poquetm/plot_energy_info.py --gantt -j output/_jobs.csv -p output/_pstate_changes.csv --off 13 --switchon '-1' --switchoff '-2'
#
# complete gantt: ./evalys-master/examples/poquetm/plot_energy_info.py --gantt -j output/_jobs.csv -p output/_pstate_changes.csv --off 13 --switchon '-1' --switchoff '-2' --ru -m output/_machine_states.csv -e output/_consumed_energy.csv --power

# %%
from evalys.jobset import JobSet
import matplotlib.pyplot as plt
import subprocess

# %%
js = JobSet.from_csv("output/_jobs.csv")
js.plot(with_details=True)
plt.show()
