# %% [markdown]
# Commandes:
#
# -simulation: batsim -p platforms/cluster21000.xml -w workload.json -e ./output/ -E
#
# -gantt: ./evalys-master/examples/poquetm/plot_energy_info.py -j output/_jobs.csv -p output/_pstate_changes.csv --off 13 --switchon '-1' --switchoff '-2'

# %%
from evalys.jobset import JobSet
import matplotlib.pyplot as plt

# %%
js = JobSet.from_csv("output/_jobs.csv")
js.plot(with_details=True)
plt.show()

# %%
# importing pandas as pd 
import pandas as pd 
  
# Check the version 
print(pd.__version__)
